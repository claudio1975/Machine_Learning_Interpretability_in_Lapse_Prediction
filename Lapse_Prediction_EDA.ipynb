# %% [markdown]
# # Machine Learning Interpretability in Lapse Prediction for Non-Life Insurance Premium

# %% [markdown]
# # Prepare Workspace

# %%
# to handle datasets
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# for statistics
import statistics as st 
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('eudirectlapse.csv')

# %% [markdown]
# # Data set Overview

# %%
# Dimensions of data set
print(df.shape)
# Out:
# (23060, 19)

# %%
# List types for each attribute
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23060 entries, 0 to 23059
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lapse                 23060 non-null  int64
#  1   polholder_age         23060 non-null  int64
#  2   polholder_BMCevol     23060 non-null  object
#  3   polholder_diffdriver  23060 non-null  object
#  4   polholder_gender      23060 non-null  object
#  5   polholder_job         23060 non-null  object
#  6   policy_age            23060 non-null  int64
#  7   policy_caruse         23060 non-null  object
#  8   policy_nbcontract     23060 non-null  int64
#  9   prem_final            23060 non-null  float64
#  10  prem_freqperyear      23060 non-null  object
#  11  prem_last             23060 non-null  float64
#  12  prem_market           23060 non-null  float64
#  13  prem_pure             23060 non-null  float64
#  14  vehicl_age            23060 non-null  int64
#  15  vehicl_agepurchase    23060 non-null  int64
#  16  vehicl_garage         23060 non-null  object
#  17  vehicl_powerkw        23060 non-null  object
#  18  vehicl_region         23060 non-null  object
# dtypes: float64(4), int64(6), object(9)
# memory usage: 3.3+ MB
# None

# %%
# Take a peek at the first rows of the data
df.head()
# Out:
#    lapse  polholder_age polholder_BMCevol polholder_diffdriver  \
# 0      0             38            stable         only partner
# 1      1             35            stable                 same
# 2      1             29            stable                 same
# 3      0             33              down                 same
# 4      0             50            stable                 same
#
#   polholder_gender polholder_job  policy_age              policy_caruse  \
# 0             Male        normal           1  private or freelance work
# 1             Male        normal           1  private or freelance work
# 2             Male        normal           0  private or freelance work
# 3           Female       medical           2  private or freelance work
# 4             Male        normal           8                    unknown
#
#    policy_nbcontract  prem_final prem_freqperyear  prem_last  prem_market  \
# 0                  1      232.46       4 per year     232.47       221.56
# 1                  1      208.53       4 per year     208.54       247.56
# 2                  1      277.34       1 per year     277.35       293.32
# 3                  1      239.51       4 per year     244.40       310.91
# 4                  1      554.54       4 per year     554.55       365.46
#
#    prem_pure  vehicl_age  vehicl_agepurchase       vehicl_garage  \
# 0     243.59           9                   8      private garage
# 1     208.54          15                   7      private garage
# 2     277.35          14                   6  underground garage
# 3     219.95          17                  10              street
# 4     519.50          16                   8              street
#
#   vehicl_powerkw vehicl_region
# 0         225 kW          Reg7
# 1         100 kW          Reg4
# 2         100 kW          Reg7
# 3          75 kW          Reg5
# 4          75 kW         Reg14

# %% [markdown]
# # Data Cleaning & Handling Variables Activity

# %% [markdown]
# ### Handling Missing Values

# %%
# Check missing values both to numeric features and categorical features 
missing = df.isnull().sum()/df.shape[0]*100
missing
# Out:
# lapse                   0.0
# polholder_age           0.0
# polholder_BMCevol       0.0
# polholder_diffdriver    0.0
# polholder_gender        0.0
# polholder_job           0.0
# policy_age              0.0
# policy_caruse           0.0
# policy_nbcontract       0.0
# prem_final              0.0
# prem_freqperyear        0.0
# prem_last               0.0
# prem_market             0.0
# prem_pure               0.0
# vehicl_age              0.0
# vehicl_agepurchase      0.0
# vehicl_garage           0.0
# vehicl_powerkw          0.0
# vehicl_region           0.0
# dtype: float64

# %%
# check duplicates
df_duplicates = df[df.duplicated()]

# %%
df_duplicates
# Out:
# Empty DataFrame
# Columns: [lapse, polholder_age, polholder_BMCevol, polholder_diffdriver, polholder_gender, polholder_job, policy_age, policy_caruse, policy_nbcontract, prem_final, prem_freqperyear, prem_last, prem_market, prem_pure, vehicl_age, vehicl_agepurchase, vehicl_garage, vehicl_powerkw, vehicl_region]
# Index: []

# %%
# Copy of a dataset for work
df_1 = df.copy()

# %% [markdown]
# # Summary Statistics

# %%
# Summarize attribute distributions for data type of variables
obj_cols = [var for var in df_1.columns if df_1[var].dtype=='object']
df_1[obj_cols].describe().T
# Out:
#                       count unique                        top   freq
# polholder_BMCevol     23060      3                     stable  12036
# polholder_diffdriver  23060      7                       same  11155
# polholder_gender      23060      2                       Male  14721
# polholder_job         23060      2                     normal  13578
# policy_caruse         23060      3  private or freelance work  19567
# prem_freqperyear      23060      4                 1 per year  11680
# vehicl_garage         23060      8             private garage   8863
# vehicl_powerkw        23060     11                      75 kW  10339
# vehicl_region         23060     14                       Reg4   4325

# %%
# Summarize attribute distributions for data type of variables
no_obj_cols = [var for var in df_1.columns if df_1[var].dtype!='object']
df_1[no_obj_cols].describe().T
# Out:
#                       count        mean         std    min       25%      50%  \
# lapse               23060.0    0.128101    0.334209   0.00    0.0000    0.000
# polholder_age       23060.0   43.045490   12.352291  19.00   35.0000   41.000
# policy_age          23060.0    2.443452    3.100771   0.00    0.0000    1.000
# policy_nbcontract   23060.0    1.305637    0.788647   1.00    1.0000    1.000
# prem_final          23060.0  374.123791  212.899174  46.55  232.8375  312.250
# prem_last           23060.0  380.508774  227.937859  46.56  232.6300  311.005
# prem_market         23060.0  373.528631  201.915809  50.11  245.1500  316.830
# prem_pure           23060.0  355.882315  197.138010  45.55  227.1000  301.445
# vehicl_age          23060.0   13.060624    3.590088   0.00   11.0000   13.000
# vehicl_agepurchase  23060.0    7.680876    4.960701   0.00    4.0000    8.000
#
#                          75%      max
# lapse                 0.0000     1.00
# polholder_age        49.0000    85.00
# policy_age            4.0000    17.00
# policy_nbcontract     1.0000    15.00
# prem_final          448.3700  2948.05
# prem_last           449.6025  3362.07
# prem_market         434.4525  2416.84
# prem_pure           423.5625  2716.08
# vehicl_age           16.0000    18.00
# vehicl_agepurchase   11.0000    18.00

# %%
# Split data set between target variable and features
X_full = df_1.copy()
y = X_full.lapse
X_full.drop(['lapse'], axis=1, inplace=True)

# %% [markdown]
# # Target Variable Analysis

# %%
# Summarize the class distribution 
count = pd.crosstab(index = y, columns="count")
percentage = pd.crosstab(index = y, columns="frequency")/pd.crosstab(index = y, columns="frequency").sum()
pd.concat([count, percentage], axis=1)
# Out:
# col_0  count  frequency
# lapse
# 0      20106   0.871899
# 1       2954   0.128101

# %%
# Plot the target variable 
fig, axes = plt.subplots(ncols=2, figsize=(10, 5), dpi=100)
pieplot = df_1.groupby('lapse').count()['polholder_age'].plot(kind='pie',ax=axes[0]).set_title("Pie Target Variable Distribution")
barplot = sns.countplot(x=df_1['lapse'], data=df_1, ax=axes[1]).set_title("Barplot Target Variable Distribution")
axes[0].set_ylabel('')

plt.show()

# %% [markdown]
# # Numerical Features Analysis

# %% [markdown]
# ### Analysis for numerical features (univariate analysis, bivariate analysis)

# %%
# Select numerical columns
numerical_cols = [cname for cname in X_full.columns if 
                X_full[cname].dtype in ['float64','int64']]

# %%
# Subset with numerical features
num = X_full[numerical_cols]
num.columns
# Out:
# Index(['polholder_age', 'policy_age', 'policy_nbcontract', 'prem_final',
#        'prem_last', 'prem_market', 'prem_pure', 'vehicl_age',
#        'vehicl_agepurchase'],
#       dtype='object')

# %%
# list of numerical features
fnum = ['polholder_age', 'policy_age', 'policy_nbcontract', 'prem_final',
       'prem_last', 'prem_market', 'prem_pure', 'vehicl_age',
       'vehicl_agepurchase']

# %%
# Univariate analysis looking at Mean, Standard Deviation, Skewness and Kurtosis
for col in fnum:
    print(col,
        '\nMean :', np.mean(num[col]),  
        '\nVariance :', np.var(num[col]),
        '\nStandard Deviation :', st.stdev(num[col]), 
        '\nSkewness :', stats.skew(num[col]), 
        '\nKurtosis :', stats.kurtosis(num[col]))
# Out:
# polholder_age
# Mean : 43.04549002601908
# Variance : 152.57247532361737
# Standard Deviation : 12.352290959026774
# Skewness : 0.8916769113608795
# Kurtosis : 0.6362468156858601
# policy_age
# Mean : 2.4434518647007804
# Variance : 9.614365187841157
# Standard Deviation : 3.1007712160297944
# Skewness : 1.3274993686778152
# Kurtosis : 0.63678564183473
# policy_nbcontract
# Mean : 1.3056374674761493
# Variance : 0.6219369960639417
# Standard Deviation : 0.788646922021973
# Skewness : 5.493284759088174
# Kurtosis : 54.653001293732075
# prem_final
# Mean : 374.12379098005215
# Variance : 45324.09287874217
# Standard Deviation : 212.89917437453818
# Skewness : 2.2403912161091886
# Kurtosis : 9.183345219215296
# prem_last
# Mean : 380.5087736339984
# Variance : 51953.41434156649
# Standard Deviation : 227.93785865026425
# Skewness : 2.244314380919726
# Kurtosis : 8.245840355569417
# prem_market
# Mean : 373.52863052905315
# Variance : 40768.22582147245
# Standard Deviation : 201.91580873655
# Skewness : 2.4064084889855963
# Kurtosis : 9.58296645821686
# prem_pure
# Mean : 355.88231483087765
# Variance : 38861.70950726088
# Standard Deviation : 197.1380095861826
# Skewness : 2.3983133012069353
# Kurtosis : 10.835098725847844
# vehicl_age
# Mean : 13.06062445793582
# Variance : 12.888172029824744
# Standard Deviation : 3.5900878751608785
# Skewness : -0.6412715041550013
# Kurtosis : 0.24340671651628876
# vehicl_agepurchase
# Mean : 7.680875975715525
# Variance : 24.607483361026027
# Standard Deviation : 4.960700607185296
# Skewness : 0.0596948244717387
# Kurtosis : -0.9167356755261662

# %%
# Univariate analysis with density plots and histograms

for col in fnum:
    plt.figure(figsize=(5,5))
    sns.displot(x=num[col], bins=10, color='green', kde=True)
    plt.xticks(rotation=45)
    plt.show()

# %%
# Univariate analysis with box-plots
for col in fnum:
    plt.figure(figsize=(5,5))
    sns.boxplot(x=num[col], color="orange")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Univariate analysis with Q-Q plot
for col in fnum:
    plt.figure(figsize=(5,5))
    res = stats.probplot(num[col], plot=plt)
    plt.title('{} Q-Q plot'.format(col))
    plt.xticks(rotation=45)
    plt.show()

# %%
# new subset for a bivariate analysis
num2 = pd.concat([y,num], axis=1)

# %%
# Bivariate analysis with box-plots
for col in fnum:
    plt.figure()
    sns.boxplot(y=col, x=y, data=num2, linewidth=2, palette="Set2")
    plt.show()

# %%
# Kendall's Test 
alpha = 0.05
for var in fnum:
    p = stats.kendalltau(num2['lapse'],num2[var])[1]
    if p <= alpha:
        print('{0} Dependent (reject H0)'.format(var))
    else:
        print('{0} Independent (fail to reject H0)'.format(var))
# Out:
# polholder_age Dependent (reject H0)
# policy_age Dependent (reject H0)
# policy_nbcontract Independent (fail to reject H0)
# prem_final Dependent (reject H0)
# prem_last Dependent (reject H0)
# prem_market Dependent (reject H0)
# prem_pure Dependent (reject H0)
# vehicl_age Dependent (reject H0)
# vehicl_agepurchase Independent (fail to reject H0)

# %% [markdown]
# # Categorical Features Analysis

# %% [markdown]
# ### Analysis for categorical features (univariate analysis, bivariate analysis)

# %%
# let's have a look at how many labels for categorical features
for col in X_full.columns:
    if X_full[col].dtype =="object":
        print(col, ': ', len(X_full[col].unique()), ' labels')
# Out:
# polholder_BMCevol :  3  labels
# polholder_diffdriver :  7  labels
# polholder_gender :  2  labels
# polholder_job :  2  labels
# policy_caruse :  3  labels
# prem_freqperyear :  4  labels
# vehicl_garage :  8  labels
# vehicl_powerkw :  11  labels
# vehicl_region :  14  labels

# %%
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_full.columns if
                    X_full[cname].nunique() <= 15 and 
                    X_full[cname].dtype == "object"]

# %%
# Subset with categorical features
cat = X_full[categorical_cols]
cat.columns
# Out:
# Index(['polholder_BMCevol', 'polholder_diffdriver', 'polholder_gender',
#        'polholder_job', 'policy_caruse', 'prem_freqperyear', 'vehicl_garage',
#        'vehicl_powerkw', 'vehicl_region'],
#       dtype='object')

# %%
# List of categorical features
fcat = ['polholder_BMCevol', 'polholder_diffdriver', 'polholder_gender',
       'polholder_job', 'policy_caruse', 'prem_freqperyear', 'vehicl_garage',
       'vehicl_powerkw', 'vehicl_region']

# %%
# Univariate analysis looking at frequency
for col in fcat:
    count = pd.crosstab(index = cat[col], columns="count")
    percentage = pd.crosstab(index = cat[col], columns="frequency")/pd.crosstab(index = cat[col], columns="frequency").sum()
    tab = pd.concat([count, percentage], axis=1)
    print('\n',tab)
# Out:
#  col_0              count  frequency
# polholder_BMCevol
# down               10155   0.440373
# stable             12036   0.521943
# up                   869   0.037684
#
#  col_0                 count  frequency
# polholder_diffdriver
# all drivers > 24       1728   0.074935
# commercial               40   0.001735
# learner 17               42   0.001821
# only partner           8128   0.352472
# same                  11155   0.483738
# unknown                  12   0.000520
# young drivers          1955   0.084779
#
#  col_0             count  frequency
# polholder_gender
# Female             8339   0.361622
# Male              14721   0.638378
#
#  col_0          count  frequency
# polholder_job
# medical         9482   0.411188
# normal         13578   0.588812
#
#  col_0                      count  frequency
# policy_caruse
# commercial                    10   0.000434
# private or freelance work  19567   0.848526
# unknown                     3483   0.151041
#
#  col_0             count  frequency
# prem_freqperyear
# 1 per year        11680   0.506505
# 12 per year        2176   0.094363
# 2 per year         3090   0.133998
# 4 per year         6114   0.265134
#
#  col_0               count  frequency
# vehicl_garage
# carport              1413   0.061275
# other                2243   0.097268
# parking deck         2243   0.097268
# private estate        199   0.008630
# private garage       8863   0.384345
# street               5468   0.237121
# underground garage   1056   0.045794
# unknown              1575   0.068300
#
#  col_0           count  frequency
# vehicl_powerkw
# 100 kW           5116   0.221856
# 125-300 kW       1720   0.074588
# 150 kW            580   0.025152
# 175 kW            206   0.008933
# 200 kW             32   0.001388
# 225 kW             77   0.003339
# 25-50 kW         4968   0.215438
# 250 kW             16   0.000694
# 275 kW              4   0.000173
# 300 kW              2   0.000087
# 75 kW           10339   0.448352
#
#  col_0          count  frequency
# vehicl_region
# Reg1             618   0.026800
# Reg10           1057   0.045837
# Reg11            558   0.024198
# Reg12           1325   0.057459
# Reg13            596   0.025846
# Reg14           1289   0.055898
# Reg2             556   0.024111
# Reg3            1827   0.079228
# Reg4            4325   0.187554
# Reg5            2391   0.103686
# Reg6            1119   0.048526
# Reg7            3156   0.136860
# Reg8            3074   0.133304
# Reg9            1169   0.050694

# %%
# Univariate analysis with barplots

for col in fcat:
    plt.figure(figsize=(5,5))
    sns.countplot(x=cat[col], data=cat, palette="Set1")
    plt.xticks(rotation=90)
    plt.show()

# %%
# new subset for a bivariate analysis
cat2 = pd.concat([y,cat], axis=1)

# %%
# Bivariate analysis with violin-plots
for col in fcat:
    plt.figure(figsize=(5,5))
    sns.violinplot(y=cat2[col], x=cat2['lapse'], linewidth=2, palette="Set2")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Bivariate analysis with barplots
for col in fcat:
    plt.figure(figsize=(10,5))
    sns.barplot(y=cat2['lapse'], x=cat2[col], palette="Set2")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Function for query and barplot about lapse per each class of variable
def query(data,col):
    # groupby
    df = data.groupby(data[col], as_index=False)['lapse'].sum()
    df['PERCENTAGE'] = df['lapse']/df['lapse'].sum()*100
    # dropping not matching rows
    df = df.dropna()
    # ranking 
    df = df.sort_values(by = 'lapse', ascending = False).reset_index(drop=True)
    df_q = df.style.background_gradient(cmap='winter').format({'PERCENTAGE': "{:.2f}"}).format({'lapse':"{:,.2f}"})
    # barplot
    index=list(df.columns[0:1])
    barplot = df[df.columns[0:2]].sort_values(by = "lapse", ascending = True).set_index(index).plot.barh()
    plt.xticks(rotation=0)
    plt.legend(loc='best', bbox_to_anchor=(1, 0.5))
    return df_q
    plt.show()
    return barplot
    plt.show()

# %%
# query and barplot
variable = 'polholder_BMCevol'
print('lapse per {}'.format(variable))
query(cat2, col='polholder_BMCevol')
# Out:
# lapse per polholder_BMCevol
# <style  type="text/css" >
# #T_3a9fe536_94f4_11ec_b451_acfdcef35164row0_col1,#T_3a9fe536_94f4_11ec_b451_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_3a9fe536_94f4_11ec_b451_acfdcef35164row1_col1,#T_3a9fe536_94f4_11ec_b451_acfdcef35164row1_col2{
#             background-color:  #00bca1;
#             color:  #000000;
#         }#T_3a9fe536_94f4_11ec_b451_acfdcef35164row2_col1,#T_3a9fe536_94f4_11ec_b451_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_3a9fe536_94f4_11ec_b451_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >polholder_BMCevol</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3a9fe536_94f4_11ec_b451_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row0_col0" class="data row0 col0" >down</td>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row0_col1" class="data row0 col1" >1,638.00</td>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row0_col2" class="data row0 col2" >55.45</td>
#             </tr>
#             <tr>
#                         <th id="T_3a9fe536_94f4_11ec_b451_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row1_col0" class="data row1 col0" >stable</td>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row1_col1" class="data row1 col1" >1,231.00</td>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row1_col2" class="data row1 col2" >41.67</td>
#             </tr>
#             <tr>
#                         <th id="T_3a9fe536_94f4_11ec_b451_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row2_col0" class="data row2 col0" >up</td>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row2_col1" class="data row2 col1" >85.00</td>
#                         <td id="T_3a9fe536_94f4_11ec_b451_acfdcef35164row2_col2" class="data row2 col2" >2.88</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'polholder_diffdriver'
print('lapse per {}'.format(variable))
query(cat2, col='polholder_diffdriver')
# Out:
# lapse per polholder_diffdriver
# <style  type="text/css" >
# #T_4c0d98be_94f4_11ec_8c49_acfdcef35164row0_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row1_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row1_col2{
#             background-color:  #00c39e;
#             color:  #000000;
#         }#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row2_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row2_col2{
#             background-color:  #003ce1;
#             color:  #f1f1f1;
#         }#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row3_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row3_col2{
#             background-color:  #0026ec;
#             color:  #f1f1f1;
#         }#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row4_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row4_col2{
#             background-color:  #0001fe;
#             color:  #f1f1f1;
#         }#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row5_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row5_col2,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row6_col1,#T_4c0d98be_94f4_11ec_8c49_acfdcef35164row6_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >polholder_diffdriver</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row0_col0" class="data row0 col0" >same</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row0_col1" class="data row0 col1" >1,367.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row0_col2" class="data row0 col2" >46.28</td>
#             </tr>
#             <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row1_col0" class="data row1 col0" >only partner</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row1_col1" class="data row1 col1" >1,043.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row1_col2" class="data row1 col2" >35.31</td>
#             </tr>
#             <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row2_col0" class="data row2 col0" >young drivers</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row2_col1" class="data row2 col1" >327.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row2_col2" class="data row2 col2" >11.07</td>
#             </tr>
#             <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row3_col0" class="data row3 col0" >all drivers > 24</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row3_col1" class="data row3 col1" >205.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row3_col2" class="data row3 col2" >6.94</td>
#             </tr>
#             <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row4_col0" class="data row4 col0" >learner 17</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row4_col1" class="data row4 col1" >8.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row4_col2" class="data row4 col2" >0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row5_col0" class="data row5 col0" >commercial</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row5_col1" class="data row5 col1" >2.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row5_col2" class="data row5 col2" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row6_col0" class="data row6 col0" >unknown</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row6_col1" class="data row6 col1" >2.00</td>
#                         <td id="T_4c0d98be_94f4_11ec_8c49_acfdcef35164row6_col2" class="data row6 col2" >0.07</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'polholder_gender'
print('Lapse per {}'.format(variable))
query(cat2, col='polholder_gender')
# Out:
# Lapse per polholder_gender
# <style  type="text/css" >
# #T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row0_col1,#T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row1_col1,#T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row1_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >polholder_gender</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row0_col1" class="data row0 col1" >1,957.00</td>
#                         <td id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row0_col2" class="data row0 col2" >66.25</td>
#             </tr>
#             <tr>
#                         <th id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row1_col0" class="data row1 col0" >Female</td>
#                         <td id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row1_col1" class="data row1 col1" >997.00</td>
#                         <td id="T_7b0fe96c_94f4_11ec_9b88_acfdcef35164row1_col2" class="data row1 col2" >33.75</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'polholder_job'
print('Lapse per {}'.format(variable))
query(cat2, col='polholder_job')
# Out:
# Lapse per polholder_job
# <style  type="text/css" >
# #T_82141130_94f4_11ec_9458_acfdcef35164row0_col1,#T_82141130_94f4_11ec_9458_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_82141130_94f4_11ec_9458_acfdcef35164row1_col1,#T_82141130_94f4_11ec_9458_acfdcef35164row1_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_82141130_94f4_11ec_9458_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >polholder_job</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82141130_94f4_11ec_9458_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_82141130_94f4_11ec_9458_acfdcef35164row0_col0" class="data row0 col0" >normal</td>
#                         <td id="T_82141130_94f4_11ec_9458_acfdcef35164row0_col1" class="data row0 col1" >1,810.00</td>
#                         <td id="T_82141130_94f4_11ec_9458_acfdcef35164row0_col2" class="data row0 col2" >61.27</td>
#             </tr>
#             <tr>
#                         <th id="T_82141130_94f4_11ec_9458_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_82141130_94f4_11ec_9458_acfdcef35164row1_col0" class="data row1 col0" >medical</td>
#                         <td id="T_82141130_94f4_11ec_9458_acfdcef35164row1_col1" class="data row1 col1" >1,144.00</td>
#                         <td id="T_82141130_94f4_11ec_9458_acfdcef35164row1_col2" class="data row1 col2" >38.73</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'policy_caruse'
print('Lapse per {}'.format(variable))
query(cat2, col='policy_caruse')
# Out:
# Lapse per policy_caruse
# <style  type="text/css" >
# #T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row0_col1,#T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row1_col1,#T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row1_col2{
#             background-color:  #001bf2;
#             color:  #f1f1f1;
#         }#T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row2_col1,#T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >policy_caruse</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row0_col0" class="data row0 col0" >private or freelance work</td>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row0_col1" class="data row0 col1" >2,661.00</td>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row0_col2" class="data row0 col2" >90.08</td>
#             </tr>
#             <tr>
#                         <th id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row1_col0" class="data row1 col0" >unknown</td>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row1_col1" class="data row1 col1" >291.00</td>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row1_col2" class="data row1 col2" >9.85</td>
#             </tr>
#             <tr>
#                         <th id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row2_col0" class="data row2 col0" >commercial</td>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row2_col1" class="data row2 col1" >2.00</td>
#                         <td id="T_9d3a5f62_94f4_11ec_a3e0_acfdcef35164row2_col2" class="data row2 col2" >0.07</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'prem_freqperyear'
print('Lapse per {}'.format(variable))
query(cat2, col='prem_freqperyear')
# Out:
# Lapse per prem_freqperyear
# <style  type="text/css" >
# #T_b19254da_94f4_11ec_a03a_acfdcef35164row0_col1,#T_b19254da_94f4_11ec_a03a_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_b19254da_94f4_11ec_a03a_acfdcef35164row1_col1,#T_b19254da_94f4_11ec_a03a_acfdcef35164row1_col2{
#             background-color:  #004ed8;
#             color:  #f1f1f1;
#         }#T_b19254da_94f4_11ec_a03a_acfdcef35164row2_col1,#T_b19254da_94f4_11ec_a03a_acfdcef35164row2_col2{
#             background-color:  #001bf2;
#             color:  #f1f1f1;
#         }#T_b19254da_94f4_11ec_a03a_acfdcef35164row3_col1,#T_b19254da_94f4_11ec_a03a_acfdcef35164row3_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_b19254da_94f4_11ec_a03a_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >prem_freqperyear</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b19254da_94f4_11ec_a03a_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row0_col0" class="data row0 col0" >1 per year</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row0_col1" class="data row0 col1" >1,638.00</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row0_col2" class="data row0 col2" >55.45</td>
#             </tr>
#             <tr>
#                         <th id="T_b19254da_94f4_11ec_a03a_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row1_col0" class="data row1 col0" >4 per year</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row1_col1" class="data row1 col1" >671.00</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row1_col2" class="data row1 col2" >22.71</td>
#             </tr>
#             <tr>
#                         <th id="T_b19254da_94f4_11ec_a03a_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row2_col0" class="data row2 col0" >2 per year</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row2_col1" class="data row2 col1" >398.00</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row2_col2" class="data row2 col2" >13.47</td>
#             </tr>
#             <tr>
#                         <th id="T_b19254da_94f4_11ec_a03a_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row3_col0" class="data row3 col0" >12 per year</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row3_col1" class="data row3 col1" >247.00</td>
#                         <td id="T_b19254da_94f4_11ec_a03a_acfdcef35164row3_col2" class="data row3 col2" >8.36</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'vehicl_garage'
print('Lapse per {}'.format(variable))
query(cat2, col='vehicl_garage')
# Out:
# Lapse per vehicl_garage
# <style  type="text/css" >
# #T_c9714ccc_94f4_11ec_b808_acfdcef35164row0_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row1_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row1_col2{
#             background-color:  #009ab2;
#             color:  #000000;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row2_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row2_col2{
#             background-color:  #003fe0;
#             color:  #f1f1f1;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row3_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row3_col2{
#             background-color:  #003ee0;
#             color:  #f1f1f1;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row4_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row4_col2{
#             background-color:  #002fe8;
#             color:  #f1f1f1;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row5_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row5_col2{
#             background-color:  #0029eb;
#             color:  #f1f1f1;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row6_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row6_col2{
#             background-color:  #0025ec;
#             color:  #f1f1f1;
#         }#T_c9714ccc_94f4_11ec_b808_acfdcef35164row7_col1,#T_c9714ccc_94f4_11ec_b808_acfdcef35164row7_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_c9714ccc_94f4_11ec_b808_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >vehicl_garage</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row0_col0" class="data row0 col0" >private garage</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row0_col1" class="data row0 col1" >1,107.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row0_col2" class="data row0 col2" >37.47</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row1_col0" class="data row1 col0" >street</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row1_col1" class="data row1 col1" >676.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row1_col2" class="data row1 col2" >22.88</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row2_col0" class="data row2 col0" >other</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row2_col1" class="data row2 col1" >286.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row2_col2" class="data row2 col2" >9.68</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row3_col0" class="data row3 col0" >parking deck</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row3_col1" class="data row3 col1" >284.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row3_col2" class="data row3 col2" >9.61</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row4_col0" class="data row4 col0" >unknown</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row4_col1" class="data row4 col1" >217.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row4_col2" class="data row4 col2" >7.35</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row5_col0" class="data row5 col0" >carport</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row5_col1" class="data row5 col1" >193.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row5_col2" class="data row5 col2" >6.53</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row6_col0" class="data row6 col0" >underground garage</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row6_col1" class="data row6 col1" >175.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row6_col2" class="data row6 col2" >5.92</td>
#             </tr>
#             <tr>
#                         <th id="T_c9714ccc_94f4_11ec_b808_acfdcef35164level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row7_col0" class="data row7 col0" >private estate</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row7_col1" class="data row7 col1" >16.00</td>
#                         <td id="T_c9714ccc_94f4_11ec_b808_acfdcef35164row7_col2" class="data row7 col2" >0.54</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'vehicl_powerkw'
print('Lapse per {}'.format(variable))
query(cat2, col='vehicl_powerkw')
# Out:
# Lapse per vehicl_powerkw
# <style  type="text/css" >
# #T_f155aa26_94f4_11ec_ae8d_acfdcef35164row0_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row1_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row1_col2{
#             background-color:  #0081be;
#             color:  #f1f1f1;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row2_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row2_col2{
#             background-color:  #0073c6;
#             color:  #f1f1f1;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row3_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row3_col2{
#             background-color:  #0026ec;
#             color:  #f1f1f1;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row4_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row4_col2{
#             background-color:  #000df8;
#             color:  #f1f1f1;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row5_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row5_col2{
#             background-color:  #0004fd;
#             color:  #f1f1f1;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row6_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row6_col2{
#             background-color:  #0001fe;
#             color:  #f1f1f1;
#         }#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row7_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row7_col2,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row8_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row8_col2,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row9_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row9_col2,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row10_col1,#T_f155aa26_94f4_11ec_ae8d_acfdcef35164row10_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >vehicl_powerkw</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row0_col0" class="data row0 col0" >75 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row0_col1" class="data row0 col1" >1,350.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row0_col2" class="data row0 col2" >45.70</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row1_col0" class="data row1 col0" >100 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row1_col1" class="data row1 col1" >682.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row1_col2" class="data row1 col2" >23.09</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row2_col0" class="data row2 col0" >25-50 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row2_col1" class="data row2 col1" >610.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row2_col2" class="data row2 col2" >20.65</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row3_col0" class="data row3 col0" >125-300 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row3_col1" class="data row3 col1" >205.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row3_col2" class="data row3 col2" >6.94</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row4_col0" class="data row4 col0" >150 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row4_col1" class="data row4 col1" >70.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row4_col2" class="data row4 col2" >2.37</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row5_col0" class="data row5 col0" >175 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row5_col1" class="data row5 col1" >25.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row5_col2" class="data row5 col2" >0.85</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row6_col0" class="data row6 col0" >225 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row6_col1" class="data row6 col1" >8.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row6_col2" class="data row6 col2" >0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row7_col0" class="data row7 col0" >200 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row7_col1" class="data row7 col1" >2.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row7_col2" class="data row7 col2" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row8_col0" class="data row8 col0" >250 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row8_col1" class="data row8 col1" >2.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row8_col2" class="data row8 col2" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row9_col0" class="data row9 col0" >275 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row9_col1" class="data row9 col1" >0.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row9_col2" class="data row9 col2" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row10_col0" class="data row10 col0" >300 kW</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row10_col1" class="data row10 col1" >0.00</td>
#                         <td id="T_f155aa26_94f4_11ec_ae8d_acfdcef35164row10_col2" class="data row10 col2" >0.00</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'vehicl_region'
print('Lapse per {}'.format(variable))
query(cat2, col='vehicl_region')
# Out:
# Lapse per vehicl_region
# <style  type="text/css" >
# #T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row0_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row1_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row1_col2{
#             background-color:  #00b4a5;
#             color:  #000000;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row2_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row2_col2{
#             background-color:  #00a8ab;
#             color:  #000000;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row3_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row3_col2{
#             background-color:  #0064cd;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row4_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row4_col2{
#             background-color:  #0063ce;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row5_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row5_col2{
#             background-color:  #005bd2;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row6_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row6_col2{
#             background-color:  #0052d6;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row7_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row7_col2{
#             background-color:  #0043de;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row8_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row8_col2{
#             background-color:  #0031e6;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row9_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row9_col2{
#             background-color:  #002fe8;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row10_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row10_col2,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row11_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row11_col2{
#             background-color:  #0016f4;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row12_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row12_col2{
#             background-color:  #000cf9;
#             color:  #f1f1f1;
#         }#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row13_col1,#T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row13_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >vehicl_region</th>        <th class="col_heading level0 col1" >lapse</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row0_col0" class="data row0 col0" >Reg4</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row0_col1" class="data row0 col1" >548.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row0_col2" class="data row0 col2" >18.55</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row1_col0" class="data row1 col0" >Reg8</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row1_col1" class="data row1 col1" >399.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row1_col2" class="data row1 col2" >13.51</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row2_col0" class="data row2 col0" >Reg7</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row2_col1" class="data row2 col1" >374.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row2_col2" class="data row2 col2" >12.66</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row3_col0" class="data row3 col0" >Reg5</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row3_col1" class="data row3 col1" >240.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row3_col2" class="data row3 col2" >8.12</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row4_col0" class="data row4 col0" >Reg12</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row4_col1" class="data row4 col1" >239.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row4_col2" class="data row4 col2" >8.09</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row5_col0" class="data row5 col0" >Reg3</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row5_col1" class="data row5 col1" >223.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row5_col2" class="data row5 col2" >7.55</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row6_col0" class="data row6 col0" >Reg14</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row6_col1" class="data row6 col1" >204.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row6_col2" class="data row6 col2" >6.91</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row7_col0" class="data row7 col0" >Reg9</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row7_col1" class="data row7 col1" >175.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row7_col2" class="data row7 col2" >5.92</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row8_col0" class="data row8 col0" >Reg10</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row8_col1" class="data row8 col1" >139.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row8_col2" class="data row8 col2" >4.71</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row9_col0" class="data row9 col0" >Reg6</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row9_col1" class="data row9 col1" >135.00</td>
#                         <td id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164row9_col2" class="data row9 col2" >4.57</td>
#             </tr>
#             <tr>
#                         <th id="T_f1f19ba8_94f4_11ec_ad85_acfdcef35164level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f1f19ba8_94f4

# %%
# Chi-Square Test
alpha = 0.05
for var in fcat:
    X = cat2[var].astype(str)
    Y = cat2['lapse'].astype(str)
    dfObserved = pd.crosstab(Y,X)
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    if p <= alpha:
    	print('{0} Dependent (reject H0)'.format(var))
    else:
       print('{0} Independent (fail to reject H0)'.format(var))
# Out:
# polholder_BMCevol Dependent (reject H0)
# polholder_diffdriver Dependent (reject H0)
# polholder_gender Dependent (reject H0)
# polholder_job Dependent (reject H0)
# policy_caruse Dependent (reject H0)
# prem_freqperyear Dependent (reject H0)
# vehicl_garage Dependent (reject H0)
# vehicl_powerkw Independent (fail to reject H0)
# vehicl_region Dependent (reject H0)
